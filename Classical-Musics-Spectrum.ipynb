# %% [markdown]
# # FREQUENCY SPECTRUMS OF CLASSICAL MUSICS

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.io.wavfile import read

# %% [markdown]
# ## CLASSIC 1:

# %%
Fs, x = read('Voices/B14_classical01.wav')

print(x.shape)
print(Fs)

xn = x[:,1]

N = len(x)
n = np.arange(0,N)

w = np.arange(-np.pi, np.pi, 2*np.pi/N)
xw = np.fft.fftshift(np.fft.fft(xn,N)/N)

print(len(w))

plt.figure()
plt.stem(w[110250:115250]*Fs/(2*np.pi),abs(xw[110250:115250]))
plt.xlabel("$Hz$")
plt.ylabel("$|X(\omega)|$")
plt.title("klasik1 $|X(\omega)|$")

#Max Noktalarının Tespiti
print("Klasik1 1")
xmax = abs(xw).max()
print("Max Y Noktası:")
print(xmax)
y = w*Fs/(2*np.pi)
ymax = y[np.argmax(abs(xw))]
print("Max X Noktası:")
print(ymax)
# Out:
# (220500, 2)
# 44100
# 220500
# <img src="data:image/png;base64,..." width="640">
# Klasik1 1
# Max Y Noktası:
# 314.17450131558326
# Max X Noktası:
# -221.80000003607054

# %% [markdown]
# ## KLASIK 2:

# %%
Fs, x = read('Voices/B14_classical02.wav')

print(x.shape)
print(Fs)

xn = x[:,1]

N = len(x)
n = np.arange(0,N)

w = np.arange(-np.pi, np.pi, 2*np.pi/N)
xw = np.fft.fftshift(np.fft.fft(xn,N)/N)

plt.figure()
plt.stem(w[110250:115250]*Fs/(2*np.pi),abs(xw[110250:115250]))
plt.xlabel("$Hz$")
plt.ylabel("$|X(\omega)|$")
plt.title("klasik2 $|X(\omega)|$")

#Max Noktalarının Tespiti
print("Klasik 2")
xmax = abs(xw).max()
print("Max Y Noktası:")
print(xmax)
y = w*Fs/(2*np.pi)
ymax = y[np.argmax(abs(xw))]
print("Max X Noktası:")
print(ymax)
# Out:
# (220500, 2)
# 44100
# <img src="data:image/png;base64,..." width="640">
# Klasik 2
# Max Y Noktası:
# 270.11320521986335
# Max X Noktası:
# 209.59999996321656

# %% [markdown]
# ## KLASIK 3:

# %%
Fs, x = read('Voices/B14_classical03.wav')

print(x.shape)
print(Fs)

xn = x[:,1]

N = len(x)
n = np.arange(0,N)

w = np.arange(-np.pi, np.pi, 2*np.pi/N)
xw = np.fft.fftshift(np.fft.fft(xn,N)/N)

plt.figure()
plt.stem(w[110250:115250]*Fs/(2*np.pi),abs(xw[110250:115250]))
plt.xlabel("$Hz$")
plt.ylabel("$|X(\omega)|$")
plt.title("klasik3 $|X(\omega)|$")

#Max Noktalarının Tespiti
print("Klasik 3")
xmax = abs(xw).max()
print("Max Y Noktası:")
print(xmax)
y = w*Fs/(2*np.pi)
ymax = y[np.argmax(abs(xw))]
print("Max X Noktası:")
print(ymax)
# Out:
# (220500, 2)
# 44100
# <img src="data:image/png;base64,..." width="640">
# Klasik 3
# Max Y Noktası:
# 232.8915366420359
# Max X Noktası:
# -373.8000000358194

# %% [markdown]
# ## KLASIK 4:

# %%
Fs, x = read('Voices/B14_classical04.wav')

print(x.shape)
print(Fs)

xn = x[:,1]

N = len(x)
n = np.arange(0,N)

w = np.arange(-np.pi, np.pi, 2*np.pi/N)
xw = np.fft.fftshift(np.fft.fft(xn,N)/N)

plt.figure()
plt.stem(w[110250:115250]*Fs/(2*np.pi),abs(xw[110250:115250]))
plt.xlabel("$Hz$")
plt.ylabel("$|X(\omega)|$")
plt.title("klasik4 $|X(\omega)|$")

#Max Noktalarının Tespiti
print("Klasik 4")
xmax = abs(xw).max()
print("Max Y Noktası:")
print(xmax)
y = w*Fs/(2*np.pi)
ymax = y[np.argmax(abs(xw))]
print("Max X Noktası:")
print(ymax)
# Out:
# (220500, 2)
# 44100
# <img src="data:image/png;base64,..." width="640">
# Klasik 4
# Max Y Noktası:
# 723.2986846059885
# Max X Noktası:
# -222.00000003607022

# %% [markdown]
# ## KLASIK 5:

# %%
Fs, x = read('Voices/B14_classical05.wav')

print(x.shape)
print(Fs)

xn = x[:,1]

N = len(x)
n = np.arange(0,N)

w = np.arange(-np.pi, np.pi, 2*np.pi/N)
xw = np.fft.fftshift(np.fft.fft(xn,N)/N)

plt.figure()
plt.stem(w[110250:115250]*Fs/(2*np.pi),abs(xw[110250:115250]))
plt.xlabel("$Hz$")
plt.ylabel("$|X(\omega)|$")
plt.title("klasik5 $|X(\omega)|$")

#Max Noktalarının Tespiti
print("Klasik 5")
xmax = abs(xw).max()
print("Max Y Noktası:")
print(xmax)
y = w*Fs/(2*np.pi)
ymax = y[np.argmax(abs(xw))]
print("Max X Noktası:")
print(ymax)
# Out:
# (220500, 2)
# 44100
# <img src="data:image/png;base64,..." width="640">
# Klasik 5
# Max Y Noktası:
# 329.0601241619476
# Max X Noktası:
# -222.00000003607022
