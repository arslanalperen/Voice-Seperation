# %% [markdown]
# # KONUSMA DOSYALARI SPEKTRUM

# %% [markdown]
# ## KONUSMA 1:

# %%
import matplotlib.pyplot as plt # grafik çizimi için gerekli kütüphanenin aktifleştirilmesi
import numpy as np
from scipy.io.wavfile import read # Ses dosyasının okunması için gerekli kütüphane

# %%
soundFile = 'Voices/konusma1.wav'
Fs, x = read(soundFile)
# %matplotlib notebook

print(x.shape) # x'in boyut bilgisi
print(Fs)
xn = x[:,1] # x'in sadece ilk sütunundaki örnekler alınmıştır (1. kanalın örnekleri)

N = len(x)
n=np.arange(0,N) # örnekleme indisinin 0'dan iki periyot olacak şekilde array olarak tanımlanması

M = 4 # Seyrek örnekleme (down sampling) oranı
xn_d = xn[np.arange(0, np.size(xn, 0), M)] # x[n] işaretinden sadece M katlarındaki örneklerin alınması
N_d = len(xn_d)
n_d = np.arange(0,N_d) # x_d[n] işaretinin indis dizisi
from IPython.lib.display import Audio
print('x[n] işareti için:')
display(Audio(xn, rate=Fs))
print('x_d[n] işareti için:')
display(Audio(xn_d, rate=Fs/M))

# klasik sinyallinin Fourier Transformu
w1 = np.arange(-np.pi, np.pi, 2*np.pi/N_d) # omega ekseninin -pi ile +pi arasında tanımlanması
xw1 = np.fft.fftshift(np.fft.fft(xn_d,N_d)/N_d) # ayrık zamanlı işaretin Fourier transformu

print(len(w1))
print(len(xw1))

plt.figure()
plt.stem(w1*Fs/(2*np.pi*M),abs(xw1)) # X(w) işaretinin grafiğinin çizdirilmesi

plt.xlabel("$Hz$") # grafiğin x ekseninin isimlendirilmesi
plt.ylabel("$|X(\omega)|$") # grafiğin y ekseninin isimlendirilmesi
plt.title("konusma1 $|X(\omega)|$") # grafiğin y ekseninin isimlendirilmesi

#Max Noktalarının Tespiti
print("Konusma 1")
xmax = abs(xw1).max()
print("Max Y Noktası:")
print(xmax)
y = w1*Fs/(2*np.pi*M)
ymax = y[np.argmax(abs(xw1))]
print("Max X Noktası:")
print(ymax)
# Out:
# (220500, 2)
# 44100
# x[n] işareti için:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# x_d[n] işareti için:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 55125
# 55125
# <img src="data:image/png;base64,..." width="640">
# Konusma 1
# Max Y Noktası:
# 171.21409633853222
# Max X Noktası:
# -629.7000000080687

# %% [markdown]
# ## KONUSMA 2:

# %%
soundFile = 'Voices/konusma2.wav'
Fs, x = read(soundFile)
# %matplotlib notebook

print(x.shape) # x'in boyut bilgisi
print(Fs)
xn = x[:,1] # x'in sadece ilk sütunundaki örnekler alınmıştır (1. kanalın örnekleri)

N = len(x)
n=np.arange(0,N) # örnekleme indisinin 0'dan iki periyot olacak şekilde array olarak tanımlanması

M = 4 # Seyrek örnekleme (down sampling) oranı
xn_d = xn[np.arange(0, np.size(xn, 0), M)] # x[n] işaretinden sadece M katlarındaki örneklerin alınması
N_d = len(xn_d)
n_d = np.arange(0,N_d) # x_d[n] işaretinin indis dizisi
from IPython.lib.display import Audio
print('x[n] işareti için:')
display(Audio(xn, rate=Fs))
print('x_d[n] işareti için:')
display(Audio(xn_d, rate=Fs/M))

# klasik sinyallinin Fourier Transformu
w1 = np.arange(-np.pi, np.pi, 2*np.pi/N_d) # omega ekseninin -pi ile +pi arasında tanımlanması
xw1 = np.fft.fftshift(np.fft.fft(xn_d,N_d)/N_d) # ayrık zamanlı işaretin Fourier transformu

print(len(w1))
print(len(xw1))

plt.figure()
plt.stem(w1*Fs/(2*np.pi*M),abs(xw1)) # X(w) işaretinin grafiğinin çizdirilmesi

plt.xlabel("$Hz$") # grafiğin x ekseninin isimlendirilmesi
plt.ylabel("$|X(\omega)|$") # grafiğin y ekseninin isimlendirilmesi
plt.title("konusma2 $|X(\omega)|$") # grafiğin y ekseninin isimlendirilmesi

#Max Noktalarının Tespiti
print("Konusma 2")
xmax = abs(xw1).max()
print("Max Y Noktası:")
print(xmax)
y = w1*Fs/(2*np.pi*M)
ymax = y[np.argmax(abs(xw1))]
print("Max X Noktası:")
print(ymax)
# Out:
# (220500, 2)
# 44100
# x[n] işareti için:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# x_d[n] işareti için:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 55125
# 55125
# <img src="data:image/png;base64,..." width="640">
# Konusma 2
# Max Y Noktası:
# 218.8855557124754
# Max X Noktası:
# -528.9000000082352

# %% [markdown]
# ## KONUSMA 3:

# %%
soundFile = 'Voices/konusma3.wav'
Fs, x = read(soundFile)
# %matplotlib notebook

print(x.shape) # x'in boyut bilgisi
print(Fs)
xn = x[:,1] # x'in sadece ilk sütunundaki örnekler alınmıştır (1. kanalın örnekleri)

N = len(x)
n=np.arange(0,N) # örnekleme indisinin 0'dan iki periyot olacak şekilde array olarak tanımlanması

M = 4 # Seyrek örnekleme (down sampling) oranı
xn_d = xn[np.arange(0, np.size(xn, 0), M)] # x[n] işaretinden sadece M katlarındaki örneklerin alınması
N_d = len(xn_d)
n_d = np.arange(0,N_d) # x_d[n] işaretinin indis dizisi
from IPython.lib.display import Audio
print('x[n] işareti için:')
display(Audio(xn, rate=Fs))
print('x_d[n] işareti için:')
display(Audio(xn_d, rate=Fs/M))

# klasik sinyallinin Fourier Transformu
w1 = np.arange(-np.pi, np.pi, 2*np.pi/N_d) # omega ekseninin -pi ile +pi arasında tanımlanması
xw1 = np.fft.fftshift(np.fft.fft(xn_d,N_d)/N_d) # ayrık zamanlı işaretin Fourier transformu

print(len(w1))
print(len(xw1))

plt.figure()
plt.stem(w1*Fs/(2*np.pi*M),abs(xw1)) # X(w) işaretinin grafiğinin çizdirilmesi

plt.xlabel("$Hz$") # grafiğin x ekseninin isimlendirilmesi
plt.ylabel("$|X(\omega)|$") # grafiğin y ekseninin isimlendirilmesi
plt.title("konusma3 $|X(\omega)|$") # grafiğin y ekseninin isimlendirilmesi

#Max Noktalarının Tespiti
print("Konusma 3")
xmax = abs(xw1).max()
print("Max Y Noktası:")
print(xmax)
y = w1*Fs/(2*np.pi*M)
ymax = y[np.argmax(abs(xw1))]
print("Max X Noktası:")
print(ymax)
# Out:
# (220500, 2)
# 44100
# x[n] işareti için:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# x_d[n] işareti için:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 55125
# 55125
# <img src="data:image/png;base64,..." width="640">
# Konusma 3
# Max Y Noktası:
# 173.5632092503943
# Max X Noktası:
# -500.90000000828155

# %% [markdown]
# ## KONUSMA 4:

# %%
soundFile = 'Voices/konusma4.wav'
Fs, x = read(soundFile)
# %matplotlib notebook

print(x.shape) # x'in boyut bilgisi
print(Fs)
xn = x[:,1] # x'in sadece ilk sütunundaki örnekler alınmıştır (1. kanalın örnekleri)

N = len(x)
n=np.arange(0,N) # örnekleme indisinin 0'dan iki periyot olacak şekilde array olarak tanımlanması

M = 4 # Seyrek örnekleme (down sampling) oranı
xn_d = xn[np.arange(0, np.size(xn, 0), M)] # x[n] işaretinden sadece M katlarındaki örneklerin alınması
N_d = len(xn_d)
n_d = np.arange(0,N_d) # x_d[n] işaretinin indis dizisi
from IPython.lib.display import Audio
print('x[n] işareti için:')
display(Audio(xn, rate=Fs))
print('x_d[n] işareti için:')
display(Audio(xn_d, rate=Fs/M))

# klasik sinyallinin Fourier Transformu
w1 = np.arange(-np.pi, np.pi, 2*np.pi/N_d) # omega ekseninin -pi ile +pi arasında tanımlanması
xw1 = np.fft.fftshift(np.fft.fft(xn_d,N_d)/N_d) # ayrık zamanlı işaretin Fourier transformu

print(len(w1))
print(len(xw1))

plt.figure()
plt.stem(w1*Fs/(2*np.pi*M),abs(xw1)) # X(w) işaretinin grafiğinin çizdirilmesi

plt.xlabel("$Hz$") # grafiğin x ekseninin isimlendirilmesi
plt.ylabel("$|X(\omega)|$") # grafiğin y ekseninin isimlendirilmesi
plt.title("konusma4 $|X(\omega)|$") # grafiğin y ekseninin isimlendirilmesi

#Max Noktalarının Tespiti
print("Konusma 4")
xmax = abs(xw1).max()
print("Max Y Noktası:")
print(xmax)
y = w1*Fs/(2*np.pi*M)
ymax = y[np.argmax(abs(xw1))]
print("Max X Noktası:")
print(ymax)
# Out:
# (220500, 2)
# 44100
# x[n] işareti için:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# x_d[n] işareti için:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 55125
# 55125
# <img src="data:image/png;base64,..." width="640">
# Konusma 4
# Max Y Noktası:
# 120.26781353550824
# Max X Noktası:
# 653.0999999898114

# %% [markdown]
# ## KONUSMA 5:

# %%
soundFile = 'Voices/konusma5.wav'
Fs, x = read(soundFile)
# %matplotlib notebook

print(x.shape) # x'in boyut bilgisi
print(Fs)
xn = x[:,1] # x'in sadece ilk sütunundaki örnekler alınmıştır (1. kanalın örnekleri)

N = len(x)
n=np.arange(0,N) # örnekleme indisinin 0'dan iki periyot olacak şekilde array olarak tanımlanması

M = 4 # Seyrek örnekleme (down sampling) oranı
xn_d = xn[np.arange(0, np.size(xn, 0), M)] # x[n] işaretinden sadece M katlarındaki örneklerin alınması
N_d = len(xn_d)
n_d = np.arange(0,N_d) # x_d[n] işaretinin indis dizisi
from IPython.lib.display import Audio
print('x[n] işareti için:')
display(Audio(xn, rate=Fs))
print('x_d[n] işareti için:')
display(Audio(xn_d, rate=Fs/M))

# klasik sinyallinin Fourier Transformu
w1 = np.arange(-np.pi, np.pi, 2*np.pi/N_d) # omega ekseninin -pi ile +pi arasında tanımlanması
xw1 = np.fft.fftshift(np.fft.fft(xn_d,N_d)/N_d) # ayrık zamanlı işaretin Fourier transformu

print(len(w1))
print(len(xw1))

plt.figure()
plt.stem(w1*Fs/(2*np.pi*M),abs(xw1)) # X(w) işaretinin grafiğinin çizdirilmesi

plt.xlabel("$Hz$") # grafiğin x ekseninin isimlendirilmesi
plt.ylabel("$|X(\omega)|$") # grafiğin y ekseninin isimlendirilmesi
plt.title("konusma5 $|X(\omega)|$") # grafiğin y ekseninin isimlendirilmesi

#Max Noktalarının Tespiti
print("Konusma 5")
xmax = abs(xw1).max()
print("Max Y Noktası:")
print(xmax)
y = w1*Fs/(2*np.pi*M)
ymax = y[np.argmax(abs(xw1))]
print("Max X Noktası:")
print(ymax)
# Out:
# (220500, 2)
# 44100
# x[n] işareti için:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# x_d[n] işareti için:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 55125
# 55125
# <img src="data:image/png;base64,..." width="640">
# Konusma 5
# Max Y Noktası:
# 131.83540095367636
# Max X Noktası:
# -575.5000000081583
