# %% [markdown]
# # MUZIK DOSYALARI SPEKTRUM

# %% [markdown]
# ## KLASIK 1:

# %%
import matplotlib.pyplot as plt # grafik çizimi için gerekli kütüphanenin aktifleştirilmesi
import numpy as np
from scipy.io.wavfile import read # Ses dosyasının okunması için gerekli kütüphane

# %%
soundFile = 'Voices/klasik1.wav'
Fs, x = read(soundFile)
# %matplotlib notebook

print(x.shape) # x'in boyut bilgisi
print(Fs)
xn = x[:,1] # x'in sadece ilk sütunundaki örnekler alınmıştır (1. kanalın örnekleri)

N = len(x)
n=np.arange(0,N) # örnekleme indisinin 0'dan iki periyot olacak şekilde array olarak tanımlanması

M = 4 # Seyrek örnekleme (down sampling) oranı
xn_d = xn[np.arange(0, np.size(xn, 0), M)] # x[n] işaretinden sadece M katlarındaki örneklerin alınması
N_d = len(xn_d)
n_d = np.arange(0,N_d) # x_d[n] işaretinin indis dizisi
from IPython.lib.display import Audio
print('x[n] işareti için:')
display(Audio(xn, rate=Fs))
print('x_d[n] işareti için:')
display(Audio(xn_d, rate=Fs/M))

# klasik sinyallinin Fourier Transformu
w1 = np.arange(-np.pi, np.pi, 2*np.pi/N_d) # omega ekseninin -pi ile +pi arasında tanımlanması
xw1 = np.fft.fftshift(np.fft.fft(xn_d,N_d)/N_d) # ayrık zamanlı işaretin Fourier transformu

print(len(w1))
print(len(xw1))

plt.figure()
plt.stem(w1*Fs/(2*np.pi*M),abs(xw1)) # X(w) işaretinin grafiğinin çizdirilmesi

plt.xlabel("$Hz$") # grafiğin x ekseninin isimlendirilmesi
plt.ylabel("$|X(\omega)|$") # grafiğin y ekseninin isimlendirilmesi
plt.title("klasik1 $|X(\omega)|$") # grafiğin y ekseninin isimlendirilmesi

#Max Noktalarının Tespiti
print("Klasik 1")
xmax = abs(xw1).max()
print("Max Y Noktası:")
print(xmax)
y = w1*Fs/(2*np.pi*M)
ymax = y[np.argmax(abs(xw1))]
print("Max X Noktası:")
print(ymax)
# Out:
# (220500, 2)
# 44100
# x[n] işareti için:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# x_d[n] işareti için:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 55125
# 55125
# <img src="data:image/png;base64,..." width="640">
# Klasik 1
# Max Y Noktası:
# 1462.1067768589985
# Max X Noktası:
# -417.10000000842

# %% [markdown]
# ## KLASIK 2:

# %%
soundFile = 'Voices/klasik2.wav'
Fs, x = read(soundFile)
# %matplotlib notebook

print(x.shape) # x'in boyut bilgisi
print(Fs)
xn = x[:,1] # x'in sadece ilk sütunundaki örnekler alınmıştır (1. kanalın örnekleri)

N = len(x)
n=np.arange(0,N) # örnekleme indisinin 0'dan iki periyot olacak şekilde array olarak tanımlanması

M = 4 # Seyrek örnekleme (down sampling) oranı
xn_d = xn[np.arange(0, np.size(xn, 0), M)] # x[n] işaretinden sadece M katlarındaki örneklerin alınması
N_d = len(xn_d)
n_d = np.arange(0,N_d) # x_d[n] işaretinin indis dizisi
from IPython.lib.display import Audio
print('x[n] işareti için:')
display(Audio(xn, rate=Fs))
print('x_d[n] işareti için:')
display(Audio(xn_d, rate=Fs/M))

# klasik sinyallinin Fourier Transformu
w1 = np.arange(-np.pi, np.pi, 2*np.pi/N_d) # omega ekseninin -pi ile +pi arasında tanımlanması
xw1 = np.fft.fftshift(np.fft.fft(xn_d,N_d)/N_d) # ayrık zamanlı işaretin Fourier transformu

print(len(w1))
print(len(xw1))

plt.figure()
plt.stem(w1*Fs/(2*np.pi*M),abs(xw1)) # X(w) işaretinin grafiğinin çizdirilmesi

plt.xlabel("$Hz$") # grafiğin x ekseninin isimlendirilmesi
plt.ylabel("$|X(\omega)|$") # grafiğin y ekseninin isimlendirilmesi
plt.title("klasik2 $|X(\omega)|$") # grafiğin y ekseninin isimlendirilmesi

#Max Noktalarının Tespiti
print("Klasik 2")
xmax = abs(xw1).max()
print("Max Y Noktası:")
print(xmax)
y = w1*Fs/(2*np.pi*M)
ymax = y[np.argmax(abs(xw1))]
print("Max X Noktası:")
print(ymax)
# Out:
# (220500, 2)
# 44100
# x[n] işareti için:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# x_d[n] işareti için:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 55125
# 55125
# <img src="data:image/png;base64,..." width="640">
# Klasik 2
# Max Y Noktası:
# 1250.7911166442034
# Max X Noktası:
# -391.100000008463

# %% [markdown]
# ## KLASIK 3:

# %%
soundFile = 'Voices/klasik3.wav'
Fs, x = read(soundFile)
# %matplotlib notebook

print(x.shape) # x'in boyut bilgisi
print(Fs)
xn = x[:,1] # x'in sadece ilk sütunundaki örnekler alınmıştır (1. kanalın örnekleri)

N = len(x)
n=np.arange(0,N) # örnekleme indisinin 0'dan iki periyot olacak şekilde array olarak tanımlanması

M = 4 # Seyrek örnekleme (down sampling) oranı
xn_d = xn[np.arange(0, np.size(xn, 0), M)] # x[n] işaretinden sadece M katlarındaki örneklerin alınması
N_d = len(xn_d)
n_d = np.arange(0,N_d) # x_d[n] işaretinin indis dizisi
from IPython.lib.display import Audio
print('x[n] işareti için:')
display(Audio(xn, rate=Fs))
print('x_d[n] işareti için:')
display(Audio(xn_d, rate=Fs/M))

# klasik sinyallinin Fourier Transformu
w1 = np.arange(-np.pi, np.pi, 2*np.pi/N_d) # omega ekseninin -pi ile +pi arasında tanımlanması
xw1 = np.fft.fftshift(np.fft.fft(xn_d,N_d)/N_d) # ayrık zamanlı işaretin Fourier transformu

print(len(w1))
print(len(xw1))

plt.figure()
plt.stem(w1*Fs/(2*np.pi*M),abs(xw1)) # X(w) işaretinin grafiğinin çizdirilmesi

plt.xlabel("$Hz$") # grafiğin x ekseninin isimlendirilmesi
plt.ylabel("$|X(\omega)|$") # grafiğin y ekseninin isimlendirilmesi
plt.title("klasik3 $|X(\omega)|$") # grafiğin y ekseninin isimlendirilmesi

#Max Noktalarının Tespiti
print("Klasik 3")
xmax = abs(xw1).max()
print("Max Y Noktası:")
print(xmax)
y = w1*Fs/(2*np.pi*M)
ymax = y[np.argmax(abs(xw1))]
print("Max X Noktası:")
print(ymax)
# Out:
# (220500, 2)
# 44100
# x[n] işareti için:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# x_d[n] işareti için:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 55125
# 55125
# <img src="data:image/png;base64,..." width="640">
# Klasik 3
# Max Y Noktası:
# 2152.1987989957806
# Max X Noktası:
# -391.100000008463

# %% [markdown]
# ## KLASIK 4:

# %%
soundFile = 'Voices/klasik4.wav'
Fs, x = read(soundFile)
# %matplotlib notebook

print(x.shape) # x'in boyut bilgisi
print(Fs)
xn = x[:,1] # x'in sadece ilk sütunundaki örnekler alınmıştır (1. kanalın örnekleri)

N = len(x)
n=np.arange(0,N) # örnekleme indisinin 0'dan iki periyot olacak şekilde array olarak tanımlanması

M = 4 # Seyrek örnekleme (down sampling) oranı
xn_d = xn[np.arange(0, np.size(xn, 0), M)] # x[n] işaretinden sadece M katlarındaki örneklerin alınması
N_d = len(xn_d)
n_d = np.arange(0,N_d) # x_d[n] işaretinin indis dizisi
from IPython.lib.display import Audio
print('x[n] işareti için:')
display(Audio(xn, rate=Fs))
print('x_d[n] işareti için:')
display(Audio(xn_d, rate=Fs/M))

# klasik sinyallinin Fourier Transformu
w1 = np.arange(-np.pi, np.pi, 2*np.pi/N_d) # omega ekseninin -pi ile +pi arasında tanımlanması
xw1 = np.fft.fftshift(np.fft.fft(xn_d,N_d)/N_d) # ayrık zamanlı işaretin Fourier transformu

print(len(w1))
print(len(xw1))

plt.figure()
plt.stem(w1*Fs/(2*np.pi*M),abs(xw1)) # X(w) işaretinin grafiğinin çizdirilmesi

plt.xlabel("$Hz$") # grafiğin x ekseninin isimlendirilmesi
plt.ylabel("$|X(\omega)|$") # grafiğin y ekseninin isimlendirilmesi
plt.title("klasik4 $|X(\omega)|$") # grafiğin y ekseninin isimlendirilmesi

#Max Noktalarının Tespiti
print("Klasik 4")
xmax = abs(xw1).max()
print("Max Y Noktası:")
print(xmax)
y = w1*Fs/(2*np.pi*M)
ymax = y[np.argmax(abs(xw1))]
print("Max X Noktası:")
print(ymax)
# Out:
# (220500, 2)
# 44100
# x[n] işareti için:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# x_d[n] işareti için:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 55125
# 55125
# <img src="data:image/png;base64,..." width="640">
# Klasik 4
# Max Y Noktası:
# 2669.705727280311
# Max X Noktası:
# 391.4999999902438

# %% [markdown]
# ## KLASIK 5:

# %%
soundFile = 'Voices/klasik5.wav'
Fs, x = read(soundFile)
# %matplotlib notebook

print(x.shape) # x'in boyut bilgisi
print(Fs)
xn = x[:,1] # x'in sadece ilk sütunundaki örnekler alınmıştır (1. kanalın örnekleri)

N = len(x)
n=np.arange(0,N) # örnekleme indisinin 0'dan iki periyot olacak şekilde array olarak tanımlanması

M = 4 # Seyrek örnekleme (down sampling) oranı
xn_d = xn[np.arange(0, np.size(xn, 0), M)] # x[n] işaretinden sadece M katlarındaki örneklerin alınması
N_d = len(xn_d)
n_d = np.arange(0,N_d) # x_d[n] işaretinin indis dizisi
from IPython.lib.display import Audio
print('x[n] işareti için:')
display(Audio(xn, rate=Fs))
print('x_d[n] işareti için:')
display(Audio(xn_d, rate=Fs/M))

# klasik sinyallinin Fourier Transformu
w1 = np.arange(-np.pi, np.pi, 2*np.pi/N_d) # omega ekseninin -pi ile +pi arasında tanımlanması
xw1 = np.fft.fftshift(np.fft.fft(xn_d,N_d)/N_d) # ayrık zamanlı işaretin Fourier transformu

print(len(w1))
print(len(xw1))

plt.figure()
plt.stem(w1*Fs/(2*np.pi*M),abs(xw1)) # X(w) işaretinin grafiğinin çizdirilmesi

plt.xlabel("$Hz$") # grafiğin x ekseninin isimlendirilmesi
plt.ylabel("$|X(\omega)|$") # grafiğin y ekseninin isimlendirilmesi
plt.title("klasik5 $|X(\omega)|$") # grafiğin y ekseninin isimlendirilmesi

#Max Noktalarının Tespiti
print("Klasik 5")
xmax = abs(xw1).max()
print("Max Y Noktası:")
print(xmax)
y = w1*Fs/(2*np.pi*M)
ymax = y[np.argmax(abs(xw1))]
print("Max X Noktası:")
print(ymax)
# Out:
# (220500, 2)
# 44100
# x[n] işareti için:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# x_d[n] işareti için:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 55125
# 55125
# <img src="data:image/png;base64,..." width="640">
# Klasik 5
# Max Y Noktası:
# 908.6261915304777
# Max X Noktası:
# -836.9000000077262
